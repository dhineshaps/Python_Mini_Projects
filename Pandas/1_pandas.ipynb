# %%
import pandas as pd

# %%
"hi"
# Out:
# 'hi'

# %%
3+2
# Out:
# 5

# %%
titanic = pd.read_csv('titanic.csv')

# %%
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df = titanic.drop(['PassengerId','Ticket','Cabin'],axis=1)

# %%
result = titanic.axes

# %%
result
# Out:
# [RangeIndex(start=0, stop=891, step=1),
#  Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#         'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#        dtype='object')]

# %%
df
# Out:
#      Survived  Pclass                                               Name  \
# 0           0       3                            Braund, Mr. Owen Harris
# 1           1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2           1       3                             Heikkinen, Miss. Laina
# 3           1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4           0       3                           Allen, Mr. William Henry
# ..        ...     ...                                                ...
# 886         0       2                              Montvila, Rev. Juozas
# 887         1       1                       Graham, Miss. Margaret Edith
# 888         0       3           Johnston, Miss. Catherine Helen "Carrie"
# 889         1       1                              Behr, Mr. Karl Howell
# 890         0       3                                Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch     Fare Embarked
# ...

# %%
#The “axes” is an attribute of the pandas DataFrame, this attribute is used to access the group of rows and columns labels of the given DataFrame

# %%
df['Age'].median()
# Out:
# np.float64(28.0)

# %%
df['Age'].fillna(df['Age'].median(), inplace=True)
# Out:
# C:\Users\Dhinesh\AppData\Local\Temp\ipykernel_14460\1933487976.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].median(), inplace=True)

# %%
df['Embarked'].mode()[0]
# Out:
# 'S'

# %%
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
# Out:
# C:\Users\Dhinesh\AppData\Local\Temp\ipykernel_14460\3744086084.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  891.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.361582    0.523008    0.381594   32.204208
# std      0.486592    0.836071   13.019697    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   22.000000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   35.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.head()
# Out:
#    Survived  Pclass                                               Name  \
# 0         0       3                            Braund, Mr. Owen Harris
# 1         1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2         1       3                             Heikkinen, Miss. Laina
# 3         1       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4         0       3                           Allen, Mr. William Henry
#
#       Sex   Age  SibSp  Parch     Fare Embarked
# 0    male  22.0      1      0   7.2500        S
# 1  female  38.0      1      0  71.2833        C
# 2  female  26.0      0      0   7.9250        S
# 3  female  35.0      1      0  53.1000        S
# 4    male  35.0      0      0   8.0500        S

# %%
tip = pd.read_csv('tips.csv')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tip[['total_bill','smoker']]
# Out:
#      total_bill smoker
# 0         16.99     No
# 1         10.34     No
# 2         21.01     No
# 3         23.68     No
# 4         24.59     No
# ..          ...    ...
# 239       29.03     No
# 240       27.18    Yes
# 241       22.67    Yes
# 242       17.82     No
# 243       18.78     No
#
# [244 rows x 2 columns]

# %%
tip['tip_percentage'] = round(tip['tip']/tip['total_bill']*100,2)

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size  tip_percentage
# 0         16.99  1.01  Female     No   Sun  Dinner     2            5.94
# 1         10.34  1.66    Male     No   Sun  Dinner     3           16.05
# 2         21.01  3.50    Male     No   Sun  Dinner     3           16.66
# 3         23.68  3.31    Male     No   Sun  Dinner     2           13.98
# 4         24.59  3.61  Female     No   Sun  Dinner     4           14.68
# ..          ...   ...     ...    ...   ...     ...   ...             ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3           20.39
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2            7.36
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2            8.82
# 242       17.82  1.75    Male     No   Sat  Dinner     2            9.82
# 243       18.78  3.00  Female     No  Thur  Dinner     2           15.97
#
# [244 rows x 8 columns]

# %%
tip.drop('tip_percentage',axis=1,inplace=True)

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#to set index

# %%
#df=df.set_index("Payment ID")

# %%
tip.iloc[0]
# Out:
# total_bill     16.99
# tip             1.01
# sex           Female
# smoker            No
# day              Sun
# time          Dinner
# size               2
# Name: 0, dtype: object

# %%
tip.iloc[0:5] #to take the sub section
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip.loc[1:1
    ]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 1       10.34  1.66  Male     No  Sun  Dinner     3

# %%
tip[tip["total_bill"]>40]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3
# 142       41.19   5.00    Male     No  Thur   Lunch     5
# 156       48.17   5.00    Male     No   Sun  Dinner     6
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4

# %%
tip["sex"]=="Male"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 239     True
# 240    False
# 241     True
# 242     True
# 243    False
# Name: sex, Length: 244, dtype: bool

# %%
tip[tip["sex"]=="Male"]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 1         10.34  1.66  Male     No  Sun  Dinner     3
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 6          8.77  2.00  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2
# 242       17.82  1.75  Male     No  Sat  Dinner     2
#
# [157 rows x 7 columns]

# %%
tip[(tip["tip"]> 3) & (tip["sex"]=="Male")]
# Out:
#      total_bill   tip   sex smoker  day    time  size
# 2         21.01  3.50  Male     No  Sun  Dinner     3
# 3         23.68  3.31  Male     No  Sun  Dinner     2
# 5         25.29  4.71  Male     No  Sun  Dinner     4
# 7         26.88  3.12  Male     No  Sun  Dinner     4
# 9         14.78  3.23  Male     No  Sun  Dinner     2
# ..          ...   ...   ...    ...  ...     ...   ...
# 206       26.59  3.41  Male    Yes  Sat  Dinner     3
# 211       25.89  5.16  Male    Yes  Sat  Dinner     4
# 212       48.33  9.00  Male     No  Sat  Dinner     4
# 232       11.61  3.39  Male     No  Sat  Dinner     2
# 239       29.03  5.92  Male     No  Sat  Dinner     3
#
# [66 rows x 7 columns]

# %%
cal = tip.loc[(tip["tip"] == 5.92) & (tip["sex"]=="Male"),'size'].item()

# %%
cal
# Out:
# 3

# %%
tim = tip.loc[(tip["tip"] == 5.92) & (tip["sex"]=="Male"),'time'].item()

# %%
tim
# Out:
# 'Dinner'

# %%
tip_male = tip[tip["sex"] == "Male"]

# %%
type(tip_male['total_bill'])
# Out:
# pandas.core.series.Series

# %%
list_male = tip_male['total_bill'].tolist()

# %%
list_male
# Out:
# [10.34,
#  21.01,
#  23.68,
#  25.29,
#  8.77,
#  26.88,
#  15.04,
#  14.78,
#  10.27,
#  15.42,
#  18.43,
#  21.58,
#  16.29,
#  20.65,
#  17.92,
#  39.42,
#  19.82,
#  17.81,
#  13.37,
#  12.69,
#  21.7,
#  9.55,
#  18.35,
#  17.78,
#  24.06,
#  16.31,
#  18.69,
#  31.27,
#  16.04,
#  17.46,
#  13.94,
#  9.68,
#  30.4,
#  18.29,
#  22.23,
#  32.4,
#  28.55,
#  18.04,
#  12.54,
#  9.94,
#  25.56,
#  19.49,
#  38.01,
#  11.24,
#  48.27,
#  20.29,
#  13.81,
#  11.02,
#  18.29,
#  17.59,
#  20.08,
#  20.23,
#  15.01,
#  12.02,
#  10.51,
#  17.92,
#  27.2,
#  22.76,
#  17.29,
#  19.44,
#  16.66,
#  32.68,
#  15.98,
#  13.03,
#  18.28,
#  24.71,
#  21.16,
#  28.97,
#  22.49,
#  40.17,
#  27.28,
#  12.03,
#  21.01,
#  12.46,
#  15.36,
#  20.49,
#  25.21,
#  18.24,
#  14.0,
#  38.07,
#  23.95,
#  29.93,
#  11.69,
#  14.26,
#  15.95,
#  8.52,
#  22.82,
#  19.08,
#  16.0,
#  34.3,
#  41.19,
#  9.78,
#  7.51,
#  14.07,
#  13.13,
#  17.26,
#  24.55,
#  19.77,
#  48.17,
#  16.49,
#  21.5,
# ...

# %%
data = pd.DataFrame([
        {"Asset": "Stock", "Name": "TCS.NS", "Qty": 5, "Avg Price": 3200},
        {"Asset": "Stock", "Name": "ITC.NS", "Qty": 5, "Avg Price": 3200},
        {"Asset": "Stock", "Name": "INFY.NS", "Qty": 5, "Avg Price": 3200},
        {"Asset": "MF", "Name": "NIFTY50", "Qty": 5, "Avg Price": 3200},
        {"Asset": "Gold", "Name": "Gold ETF", "Qty": 10, "Avg Price": None}
    ])

# %%
data
# Out:
#    Asset      Name  Qty  Avg Price
# 0  Stock    TCS.NS    5     3200.0
# 1  Stock    ITC.NS    5     3200.0
# 2  Stock   INFY.NS    5     3200.0
# 3     MF   NIFTY50    5     3200.0
# 4   Gold  Gold ETF   10        NaN

# %%
qty = data.loc[(data["Asset"] == "Stock") & (data["Name"] == "ITC.NS"), "Qty"].item()

# %%
avg_price = data.loc[(data["Asset"] == "Stock") & (data["Name"] == "ITC.NS"), "Avg Price"].item()

# %%
avg_price
# Out:
# 3200.0

# %%
data[(data["Asset"] == "Stock") & ((data["Name"]))]
# Out:
#    Asset     Name  Qty  Avg Price
# 0  Stock   TCS.NS    5     3200.0
# 1  Stock   ITC.NS    5     3200.0
# 2  Stock  INFY.NS    5     3200.0

# %%
stock_list = data.loc[(data["Asset"] == "Stock") , "Name"].tolist()

# %%
stock_list
# Out:
# ['TCS.NS', 'ITC.NS', 'INFY.NS']

# %%
data["Name"].split(".")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14460\3006538229.py in ?()
# ----> 1 data["Name"].split(".")
#
# c:\VS_Code\fetquest-env\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6314             and name not in self._accessors
#    6315             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316         ):
#    6317             return self[name]
# -> 6318         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
stock = pd.read_csv('C://VS_Code//Python_Works//fetquest-Stocklytics//nse_equity.csv')

# %%
stock
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 Microns Limited      EQ
# 1     21STCENMGM  21st Century Management Services Limited      EQ
# 2         360ONE                       360 ONE WAM LIMITED      EQ
# 3      3IINFOLTD                       3i Infotech Limited      EQ
# 4        3MINDIA                          3M India Limited      EQ
# ...          ...                                       ...     ...
# 2165        ZOTA                  Zota Health Care LImited      EQ
# 2166       ZUARI              Zuari Agro Chemicals Limited      EQ
# 2167    ZUARIIND                  ZUARI INDUSTRIES LIMITED      EQ
# 2168   ZYDUSLIFE                Zydus Lifesciences Limited      EQ
# 2169   ZYDUSWELL                    Zydus Wellness Limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
cos = stock['NAME OF COMPANY'].tolist()

# %%
cos
# Out:
# ['20 Microns Limited',
#  '21st Century Management Services Limited',
#  '360 ONE WAM LIMITED',
#  '3i Infotech Limited',
#  '3M India Limited',
#  '3P Land Holdings Limited',
#  '5Paisa Capital Limited',
#  '63 moons technologies limited',
#  'A2Z Infra Engineering Limited',
#  'AAA Technologies Limited',
#  'Aadhar Housing Finance Limited',
#  'Aakash Exploration Services Limited',
#  'Aarey Drugs & Pharmaceuticals Limited',
#  'Aaron Industries Limited',
#  'Aartech Solonics Limited',
#  'Aarti Drugs Limited',
#  'Aarti Industries Limited',
#  'Aarti Pharmalabs Limited',
#  'Aarti Surfactants Limited',
#  'Aarvee Denims & Exports Limited',
#  'Aarvi Encon Limited',
#  'Aavas Financiers Limited',
#  'Aban Offshore Limited',
#  'ABB India Limited',
#  'Abbott India Limited',
#  'Aditya Birla Capital Limited',
#  'Allied Blenders and Distillers Limited',
#  'Aditya Birla Fashion and Retail Limited',
#  'A B Infrabuild Limited',
#  'Aditya Birla Lifestyle Brands Limited',
# ...

# %%
stock_symbol = stock.loc[stock["NAME OF COMPANY"] == "3M India Limited","SYMBOL"].item()
# Out:
# '3MINDIA'

# %%
stock["NAME OF COMPANY"] = stock["NAME OF COMPANY"].str.lower()

# %%
stock
# Out:
#           SYMBOL                           NAME OF COMPANY  SERIES  \
# 0      20MICRONS                        20 microns limited      EQ
# 1     21STCENMGM  21st century management services limited      EQ
# 2         360ONE                       360 one wam limited      EQ
# 3      3IINFOLTD                       3i infotech limited      EQ
# 4        3MINDIA                          3m india limited      EQ
# ...          ...                                       ...     ...
# 2165        ZOTA                  zota health care limited      EQ
# 2166       ZUARI              zuari agro chemicals limited      EQ
# 2167    ZUARIIND                  zuari industries limited      EQ
# 2168   ZYDUSLIFE                zydus lifesciences limited      EQ
# 2169   ZYDUSWELL                    zydus wellness limited      EQ
#
#       DATE OF LISTING   PAID UP VALUE   MARKET LOT   ISIN NUMBER   FACE VALUE
# 0         06-OCT-2008               5            1  INE144J01027            5
# ...

# %%
stock_symbol = stock.loc[stock["NAME OF COMPANY"] == "zuari agro chemicals limited","SYMBOL"].item()

# %%
stock_symbol
# Out:
# 'ZUARI'

# %%
mf = pd.read_csv('C://VS_Code//Python_Works//fetquest-Stocklytics//amfi_mutual_fund_list.csv')

# %%
mf
# Out:
#        Scheme Code                                        Scheme Name  \
# 0           119551  Aditya Birla Sun Life Banking & PSU Debt Fund ...
# 1           119552  Aditya Birla Sun Life Banking & PSU Debt Fund ...
# 2           119553  Aditya Birla Sun Life Banking & PSU Debt Fund ...
# 3           108272  Aditya Birla Sun Life Banking & PSU Debt Fund ...
# 4           110282  Aditya Birla Sun Life Banking & PSU Debt Fund ...
# ...            ...                                                ...
# 13997       109618  UTI Quarterly Interval Fund - II - Regular Pla...
# 13998       121722  UTI Quarterly Interval Fund - III -Direct Plan...
# 13999       121721  UTI Quarterly Interval Fund - III -Direct Plan...
# 14000       110024  UTI Quarterly Interval Fund - III -Regular Pla...
# 14001       110021  UTI Quarterly Interval Fund - III -Regular Pla...
#
#       ISIN Div Payout/ ISIN Growth ISIN Div Reinvestment Net Asset Value  \
# ...

# %%
fund_name = "Aditya Birla Sun Life Banking & PSU Debt Fund  - DIRECT - MONTHLY IDCW"

# %%
match = mf.loc[mf["Scheme Name"] == fund_name,"ISIN Div Payout/ ISIN Growth"]

# %%
match
# Out:
# 1    INF209K01YM2
# Name: ISIN Div Payout/ ISIN Growth, dtype: object

# %%
match = mf.loc[mf["Scheme Name"] == fund_name,"ISIN Div Payout/ ISIN Growth"]

# %%
match
# Out:
# 1    INF209K01YM2
# Name: ISIN Div Payout/ ISIN Growth, dtype: object

# %%
s = {'message': 'duplicate key value violates unique constraint "fet_portfolio_holdings_pkey"', 'code': '23505', 'hint': None, 'details': 'Key (asset)=(itc limited) already exists.'}

# %%
k = str(s)

# %%
k.split(",")[3].split("=")[1].split("(")[1].split(")")[0]
# Out:
# 'itc limited'

# %%
k.split(",")[3]
# Out:
# " 'details': 'Key (asset)=(itc limited) already exists.'}"

# %%
import yfinance as yf

# %%
reliance = yf.Ticker("RELIANCE.NS")
reliance.info.get("currentPrice")
reliance.info.get("industry", "N/A")
reliance.info.get("sectorKey", "N/A")
reliance.info.get("bookValue")
reliance.info.get("priceToBook")
reliance.info.get("marketCap")
# Out:
# 18688344326144

# %%
reliance.analyst_price_targets
# Out:
# {'current': 1359.3,
#  'high': 1850.0,
#  'low': 1300.0,
#  'mean': 1640.4572,
#  'median': 1660.0}

# %%
reliance.recommendations
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m         11   21     1     1           1
# 1    -1m         12   20     1     1           1
# 2    -2m         12   19     1     1           1
# 3    -3m         12   20     1     1           1

# %%
reliance.eps_trend
# Out:
#          current  7daysAgo  30daysAgo  60daysAgo  90daysAgo
# period
# 0q      14.50028    14.645   13.79667     14.295     14.295
# +1q     15.17033    15.650   14.61667     15.560     15.560
# 0y      26.40000    26.400   27.90000     37.050     37.050
# +1y     25.90000    25.900   29.25000     39.250     39.250

# %%
reliance.recommendations['strongBuy'].iloc[0]
# Out:
# np.int64(11)

# %%
reliance.recommendations['strongBuy']
# Out:
# 0    11
# 1    12
# 2    12
# 3    12
# Name: strongBuy, dtype: int64

# %%
df = yf.download("RELIANCE.NS", period="1mo")
max_high = df['High'].max().iloc[0]
min_low = df ['Low'].min().iloc[0]
# Out:
# C:\Users\Dhinesh\AppData\Local\Temp\ipykernel_18848\1708903062.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("RELIANCE.NS", period="1mo")
# [*********************100%***********************]  1 of 1 completed

# %%
max_high
# Out:
# np.float64(1431.9000244140625)

# %%
min_low
# Out:
# np.float64(1340.5999755859375)

# %%
df
# Out:
# Price             Close         High          Low         Open      Volume
# Ticker      RELIANCE.NS  RELIANCE.NS  RELIANCE.NS  RELIANCE.NS RELIANCE.NS
# Date
# 2025-08-04  1405.885010  1410.466687  1386.163726  1389.550225     6312820
# 2025-08-05  1386.163696  1405.386969  1382.578042  1405.386969     9315972
# 2025-08-06  1387.259521  1390.347165  1377.797312  1386.363077     5834312
# 2025-08-07  1383.872925  1388.155746  1360.565987  1382.179615     9976705
# 2025-08-08  1362.358887  1391.641835  1359.569977  1379.490416     8793606
# 2025-08-11  1380.685669  1382.478557  1355.785119  1364.550161     9997486
# 2025-08-12  1374.908813  1396.323287  1369.729426  1376.402846    12244664
# 2025-08-13  1377.099976  1386.263451  1372.020288  1382.478519     7457021
# 2025-08-14  1373.800049  1380.699951  1370.099976  1377.300049     7126128
# 2025-08-18  1381.699951  1394.900024  1377.000000  1390.000000    11785109
# ...

# %%
print(df[('Close', 'RELIANCE.NS')].iloc[-2])
print(df[('Close', 'RELIANCE.NS')].iloc[-15])
# Out:
# 1372.5999755859375
# 1373.800048828125

# %%
try:
    df[('Close', 'RELIANCE.NS')].iloc[-30]
except:
    print("error in getting the data")
# Out:
# error in getting the data

# %%
reliance.info.get("debtToEquity")
# Out:
# 36.605

# %%
data = yf.download("ITC", period="1y")
# Out:
# C:\Users\Dhinesh\AppData\Local\Temp\ipykernel_18848\2471351659.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download("ITC", period="1y")
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['ITC']: YFPricesMissingError('possibly delisted; no price data found  (period=1y)')

# %%
df = yf.download("RELIANCE.NS", period="1y")
# Out:
# C:\Users\Dhinesh\AppData\Local\Temp\ipykernel_18848\1323053827.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download("RELIANCE.NS", period="1y")
# [*********************100%***********************]  1 of 1 completed

# %%
df["High"].max().iloc[0]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 df["High"].max().iloc[0].getItem()
#
# AttributeError: 'numpy.float64' object has no attribute 'getItem'

# %%
df["High"].min().iloc[0]
# Out:
# np.float64(1166.590714623955)
